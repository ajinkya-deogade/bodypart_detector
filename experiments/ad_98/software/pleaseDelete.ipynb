# %%
import pandas as pd

# %%
coordinate_header = ['FrameNumber', 'MouthHook_x', 'MouthHook_y', 'LeftMHhook_x', 'LeftMHhook_y',
                     'RightMHhook_x', 'RightMHhook_y', 'LeftDorsalOrgan_x', 'LeftDorsalOrgan_y',
                     'RightDorsalOrgan_x', 'RightDorsalOrgan_y', 'CenterBolwigOrgan_x', 'CenterBolwigOrgan_y',
                     'LeftBolwigOrgan_x', 'LeftBolwigOrgan_y', 'RightBolwigOrgan_x', 'RightBolwigOrgan_y']
dat = pd.read_csv('/Users/ajinkyadeogade/work/mhdo/experiments/ad_98/expts/dataCollectedOn_20180417_withTestOn_20180619/dataCollectedOn_2018041_grp_19/20180529_151947/Rawdata_20180417_075246_20180420_092232_A_095851/Rawdata_20180417_075246_20180420_092232_A_095851_Coordinates.csv', sep=',', names=coordinate_header)

# %%
dat.groupby('FrameNumber').mean()
# Out:
#              MouthHook_x  MouthHook_y  LeftMHhook_x  LeftMHhook_y  \
# FrameNumber
# 31           1577.147570   600.463407   1585.764247    575.228854
# 32           1576.915417   599.616977   1587.994001    573.151470
# 33           1581.377325   602.463407   1589.378524    571.074085
# 34           1578.068986   602.770546   1585.454709    573.843131
# 35           1576.223755   600.925315   1579.301140    571.997900
# 36           1544.680864   602.540792   1548.373725    572.382424
# 37           1541.915417   600.693161   1543.761848    574.843131
# 38           1541.454709   601.463407   1544.532094    571.920516
# 39           1547.302340   603.309838   1541.147570    578.075285
# 40           1549.686863   606.925315   1542.301140    580.459808
# 41           1551.147570   598.230054   1550.532094    568.071686
# 42           1554.844031   600.696761   1556.690462    573.000300
# 47           1474.608278   432.614577   1491.841632    393.839532
# ...

# %%
dat_2 = dat.groupby('FrameNumber').mean()
dat_2.reset_index(inplace=True)

# %%
print "dat ", dat.shape
print "dat_2 ", dat_2.shape
# Out:
# dat  (664, 17)
# dat_2  (376, 17)

# %%
dat_2.to_csv('/Users/ajinkyadeogade/work/mhdo/experiments/ad_98/expts/dataCollectedOn_20180417_withTestOn_20180619/dataCollectedOn_2018041_grp_19/20180529_151947/Rawdata_20180417_075246_20180420_092232_A_095851/Rawdata_20180417_075246_20180420_092232_A_095851_Coordinates.csv', sep=',', header=False, index=False)
